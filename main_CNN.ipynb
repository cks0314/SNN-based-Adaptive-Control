# %%
# import libraries
import math

import numpy
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing
import itertools
import torch
import random
import time
from sklearn import preprocessing
import scipy.io

from net import MainNet
from dynamics.robot_selector import robot_selector
from dynamics.data_gen_robot import data_gen_robot_multi

# %%
robot_type = "3R"
modality = "3D"

# %%
# robot pars
robot_pars = {}
robot_pars['m'] = 0.6
robot_pars['l'] = 1
robot_pars['I'] = (robot_pars['m']/(robot_pars['l']**2))*np.diag([0,1,1])/12
robot_pars['G'] = 1
robot_pars['B'] = 0
robot_pars['T'] = 0

# %%
# robot parameters changed
robot_pars_changed = {}
robot_pars_changed['m'] = 0.6+(-5*0.06)
robot_pars_changed['l'] = 1.0   # 1
robot_pars_changed['I'] = (robot_pars_changed['m']/(robot_pars_changed['l']**2))*np.diag([0,1,1])/12
robot_pars_changed['G'] = 1
robot_pars_changed['B'] = 0
robot_pars_changed['T'] = 0

robot_pars_changed['state_noise'] = True
robot_pars_changed['state_noise_type'] = 'gaussian' # constant, sinosoidal, gaussian, 'random'
SNR_DB_state = 25
robot_pars_changed ['SN_state'] = (10**(SNR_DB_state/20))

robot_pars_changed ['ext_torque'] = False
SNR_DB_input = 10
robot_pars_changed ['ext_torque_type'] = 'gaussian' # constant, sinosoidal, gaussian, 'random'
robot_pars_changed ['SN_input'] = (10**(SNR_DB_input/20))

# %%
robot_name = robot_type + "_" + modality
robot = robot_selector(robot_name,robot_pars)
robot_changed = robot_selector(robot_name,robot_pars_changed)

# %%
dt = 0.01  #time step
num_train = 120  # no. of training examples
num_val = int(0.25 * num_train)  # no of testing examples
num_traj = num_train + num_val  #no of trajectories
num_snaps = 100  # no. of snapshots
controller = 'controller'  # controller used or not for data generation
num_joints = robot.random_q().shape[0]
num_states = 2 * robot.random_q().shape[0]
num_inputs = num_joints

T = np.linspace(0, num_snaps * dt, num_snaps)

# %%
state_data,_, _, _, input_data = data_gen_robot_multi(dt,num_traj,num_snaps, robot, robot_changed, robot_pars_changed, controller)

# %%
state_data.shape, input_data.shape
# Out:
# ((150, 100, 6), (150, 99, 3))

# %%
# state_data = np.random.rand(100,151,6)
# input_data = np.random.rand(100,150,3)

# %%
num_states = state_data.shape[2]
num_joints = int(num_states/2)
ctrl_dim = input_data.shape[2]

num_traj = state_data.shape[0]
num_snaps = input_data.shape[1]

dt = 0.01

# %%
accln = (state_data[:,1:,num_joints:] - state_data[:,:-1,num_joints:])/dt

# %%
plt.figure(figsize = (10,10))
for i in range(num_traj):
    for j in range(num_joints):
        plt.subplot(3,1,j+1)
        plt.plot(accln[i,:,j])
        plt.xlabel('t')
        plt.ylabel('th_'+str(j+1))
plt.show()

# %%
plt.figure(figsize = (10,10))
for i in range(num_traj):
    for j in range(num_joints):
        plt.subplot(3,1,j+1)
        plt.plot(input_data[i,:,j])
        plt.xlabel('t')
        plt.ylabel('th_dot_'+str(j+1))
plt.show()

# %%
FC_neurons = 100
Conv_RELU = 100
Conv = 200

net_params = {}
net_params['num_joints'] = num_joints
net_params["input_dim"] = num_states
net_params['output_dim'] = num_inputs
net_params['FC_layers'] = [FC_neurons, FC_neurons, num_joints]
net_params['Conv_layers_RELU'] = [3, Conv_RELU, [1, 1]] # [in_channels, out_channels, kernel_size (height), width]
net_params['Conv_layers'] = [Conv_RELU, Conv, [1, 1]]
net_params['dim_layer_a'] = Conv
net_params['optimizer'] = 'adam'
net_params['standardize'] = 'True'
net_params['l1_reg'] = 2e-1
net_params['l2_reg'] = 2e-1
net_params['lr'] = 1e-4
net_params['epochs'] = 500
net_params['batch_size'] = 256
net_params['activation_FC'] = 'relu'
net_params['activation_Conv'] = 'relu'

# %%
X = np.concatenate((state_data[:,:-1,:], accln), axis = 2)

# %%
X.shape
# Out:
# (150, 99, 9)

# %%
xs_train, us_train = X[:num_train,:,:], input_data[:num_train,:,:]
xs_val, us_val = X[num_train:,:,:], input_data[num_train:,:,:]

# %%
xs_train.shape, us_train.shape
# Out:
# ((120, 99, 9), (120, 99, 3))

# %%
from net import TrainNet
# from torchviz import make_dot
import hiddenlayer as hl
from core.util import fit_standardizer

# %%
xs_train.shape, us_train.shape
# Out:
# ((120, 99, 9), (120, 99, 3))

# %%
Train = True
if Train:
    network = MainNet(net_params)
    train_network = TrainNet(network)
    train_network.model_pipeline(xs_train, us_train, xs_val, us_val)
    torch.save(train_network,'saved_network/'+'num_traj'+str(num_train)+'cnn_arch.pth')
else:
    train_network = torch.load('NN_arch.pth')
    network = train_network.net
# Out:
# Epoch   1: train loss: 421.6048583984, validation loss: 396.0730946859
# Epoch   2: train loss: 393.6118164062, validation loss: 368.8773727417
# Epoch   3: train loss: 366.8034057617, validation loss: 343.0550842285
# Epoch   4: train loss: 341.5672302246, validation loss: 318.6398366292
# Epoch   5: train loss: 317.6445617676, validation loss: 295.4926516215
# Epoch   6: train loss: 295.0272827148, validation loss: 273.7186609904
# Epoch   7: train loss: 273.7561645508, validation loss: 253.1425755819
# Epoch   8: train loss: 253.8793182373, validation loss: 233.9961649577
# Epoch   9: train loss: 235.4559783936, validation loss: 216.2391993205
# Epoch  10: train loss: 218.3466186523, validation loss: 199.6298408508
# Epoch  11: train loss: 202.1156463623, validation loss: 184.4916826884
# Epoch  12: train loss: 187.3646697998, validation loss: 170.3839607239
# Epoch  13: train loss: 174.0727081299, validation loss: 157.7454859416
# Epoch  14: train loss: 161.9625091553, validation loss: 146.3300196330
# Epoch  15: train loss: 151.3345184326, validation loss: 136.1719169617
# Epoch  16: train loss: 141.3783416748, validation loss: 127.1439228058
# Epoch  17: train loss: 133.0367584229, validation loss: 119.3979600271
# Epoch  18: train loss: 126.0220489502, validation loss: 112.9414742788
# Epoch  19: train loss: 119.5534515381, validation loss: 107.3126118978
# Epoch  20: train loss: 114.9485244751, validation loss: 103.2922598521
# Epoch  21: train loss: 110.9770736694, validation loss: 100.7946186066
# Epoch  22: train loss: 108.5905838013, validation loss: 97.9133872986
# Epoch  23: train loss: 107.0221099854, validation loss: 96.8243624369
# Epoch  24: train loss: 105.4386825562, validation loss: 95.5631376902
# Epoch  25: train loss: 104.1626281738, validation loss: 95.4607302348
# Epoch  26: train loss: 103.1759338379, validation loss: 93.3467750549
# Epoch  27: train loss: 102.2720565796, validation loss: 92.6227296193
# Epoch  28: train loss: 100.9829406738, validation loss: 91.6841983795
# Epoch  29: train loss: 100.0970458984, validation loss: 90.7465343475
# Epoch  30: train loss: 99.4061279297, validation loss: 89.8940807978
# Epoch  31: train loss: 98.0953063965, validation loss: 88.9486904144
# Epoch  32: train loss: 97.2468643188, validation loss: 87.9887755712
# Epoch  33: train loss: 96.5557250977, validation loss: 87.4146366119
# Epoch  34: train loss: 95.5384292603, validation loss: 86.3344306946
# Epoch  35: train loss: 95.0280914307, validation loss: 85.2831506729
# Epoch  36: train loss: 94.1842880249, validation loss: 84.9453999201
# Epoch  37: train loss: 93.2171630859, validation loss: 84.2334690094
# Epoch  38: train loss: 92.5240631104, validation loss: 83.5478429794
# Epoch  39: train loss: 91.8819732666, validation loss: 82.4836591085
# Epoch  40: train loss: 91.1927642822, validation loss: 81.9091078440
# Epoch  41: train loss: 90.6281890869, validation loss: 81.1134703954
# Epoch  42: train loss: 89.8852310181, validation loss: 80.7754360835
# Epoch  43: train loss: 89.0348129272, validation loss: 80.1244678497
# Epoch  44: train loss: 88.7210769653, validation loss: 79.1109135946
# Epoch  45: train loss: 87.9618377686, validation loss: 79.0355908076
# Epoch  46: train loss: 87.5488891602, validation loss: 78.3130089442
# Epoch  47: train loss: 86.7560119629, validation loss: 77.9334332148
# Epoch  48: train loss: 86.3000183105, validation loss: 76.9673229853
# Epoch  49: train loss: 85.4218673706, validation loss: 76.5702285767
# Epoch  50: train loss: 84.8383712769, validation loss: 75.8142954508
# Epoch  51: train loss: 84.6328201294, validation loss: 75.3485240936
# Epoch  52: train loss: 83.8711471558, validation loss: 75.5676940282
# Epoch  53: train loss: 83.2972259521, validation loss: 73.9887781143
# Epoch  54: train loss: 83.0428619385, validation loss: 74.8356227875
# Epoch  55: train loss: 82.2741928101, validation loss: 73.3909247716
# Epoch  56: train loss: 81.9233093262, validation loss: 73.4551712672
# Epoch  57: train loss: 81.3067321777, validation loss: 72.7243315379
# Epoch  58: train loss: 81.0374832153, validation loss: 72.1696100235
# Epoch  59: train loss: 80.6107254028, validation loss: 71.5073712667
# Epoch  60: train loss: 79.8749542236, validation loss: 71.3858629862
# Epoch  61: train loss: 79.5500183105, validation loss: 70.9906946818
# Epoch  62: train loss: 79.1736755371, validation loss: 70.5681540171
# Epoch  63: train loss: 78.8329391479, validation loss: 69.8382922808
# Epoch  64: train loss: 78.3378524780, validation loss: 69.9810091654
# Epoch  65: train loss: 77.8526458740, validation loss: 69.2858622869
# Epoch  66: train loss: 77.9374618530, validation loss: 69.1496934891
# Epoch  67: train loss: 77.4227294922, validation loss: 68.9424947103
# Epoch  68: train loss: 76.8962631226, validation loss: 68.7975956599
# Epoch  69: train loss: 76.6187973022, validation loss: 68.5836524963
# Epoch  70: train loss: 76.1277313232, validation loss: 68.7069212596
# Epoch  71: train loss: 76.0010986328, validation loss: 67.8926630020
# Epoch  72: train loss: 75.4539642334, validation loss: 67.4920002619
# Epoch  73: train loss: 75.2343978882, validation loss: 66.4504453341
# Epoch  74: train loss: 74.9668350220, validation loss: 66.8334735235
# Epoch  75: train loss: 74.7591705322, validation loss: 66.3605504036
# Epoch  76: train loss: 74.1680755615, validation loss: 65.7580582301
# Epoch  77: train loss: 73.9132919312, validation loss: 65.7257652283
# Epoch  78: train loss: 73.7076263428, validation loss: 65.7963527044
# Epoch  79: train loss: 73.5996475220, validation loss: 65.3916591009
# Epoch  80: train loss: 73.2544708252, validation loss: 65.3934138616
# Epoch  81: train loss: 73.3348541260, validation loss: 64.9474951426
# Epoch  82: train loss: 72.7524490356, validation loss: 64.6339538892
# Epoch  83: train loss: 72.4908370972, validation loss: 64.8395706813
# Epoch  84: train loss: 72.4141464233, validation loss: 64.3422546387
# Epoch  85: train loss: 72.1925506592, validation loss: 64.8822495143
# Epoch  86: train loss: 72.1468048096, validation loss: 64.7187916438
# Epoch  87: train loss: 71.9343338013, validation loss: 64.2394351959
# Epoch  88: train loss: 71.5489501953, validation loss: 64.6828384399
# Epoch  89: train loss: 71.5873870850, validation loss: 63.5053121249
# Epoch  90: train loss: 71.5781478882, validation loss: 63.5384960175
# Epoch  91: train loss: 71.3532028198, validation loss: 63.9570425351
# Epoch  92: train loss: 71.4653396606, validation loss: 62.6453744570
# Epoch  93: train loss: 71.0508880615, validation loss: 62.8433721860
# Epoch  94: train loss: 70.6858825684, validation loss: 62.6796236038
# Epoch  95: train loss: 70.8972015381, validation loss: 62.9963305791
# Epoch  96: train loss: 70.7117462158, validation loss: 63.4757359823
# Epoch  97: train loss: 70.9522247314, validation loss: 62.9570144018
# Epoch  98: train loss: 70.3259429932, validation loss: 62.0963290532
# Epoch  99: train loss: 70.6223526001, validation loss: 61.6266283989
# Epoch 100: train loss: 70.4834213257, validation loss: 62.3711638451
# Epoch 101: train loss: 70.3331985474, validation loss: 63.1191234589
# Epoch 102: train loss: 69.8696060181, validation loss: 61.9798806508
# Epoch 103: train loss: 70.0949096680, validation loss: 61.8663059870
# Epoch 104: train loss: 69.8955154419, validation loss: 61.7061244647
# Epoch 105: train loss: 69.7102737427, validation loss: 61.8704423904
# Epoch 106: train loss: 69.4321670532, validation loss: 62.1051236788
# Epoch 107: train loss: 69.5742721558, validation loss: 61.4512346586
# Epoch 108: train loss: 69.6078338623, validation loss: 61.2234268188
# Epoch 109: train loss: 69.3879928589, validation loss: 61.6039802233
# Epoch 110: train loss: 69.1885299683, validation loss: 61.3361104329
# Epoch 111: train loss: 69.3832931519, validation loss: 62.0804953575
# Epoch 112: train loss: 69.2462005615, validation loss: 61.4523924192
# Epoch 113: train loss: 69.1063461304, validation loss: 61.1156498591
# Epoch 114: train loss: 68.8988037109, validation loss: 61.2911990484
# Epoch 115: train loss: 68.7555160522, validation loss: 61.4905702273
# Epoch 116: train loss: 68.7250900269, validation loss: 61.3421449661
# Epoch 117: train loss: 68.7093582153, validation loss: 60.8470904032
# Epoch 118: train loss: 68.4220504761, validation loss: 60.5940807660
# Epoch 119: train loss: 68.5710067749, validation loss: 60.9512507121
# Epoch 120: train loss: 68.6506805420, validation loss: 60.3277220726
# Epoch 121: train loss: 68.5054855347, validation loss: 60.0521237055
# Epoch 122: train loss: 68.4346084595, validation loss: 60.8699049950
# Epoch 123: train loss: 68.6131896973, validation loss: 60.1454354922
# Epoch 124: train loss: 68.4169998169, validation loss: 60.5894422531
# Epoch 125: train loss: 68.4803466797, validation loss: 60.3755974770
# Epoch 126: train loss: 68.3943786621, validation loss: 60.2015163104
# Epoch 127: train loss: 68.2969512939, validation loss: 61.3893917402
# Epoch 128: train loss: 68.2432098389, validation loss: 60.2033985456
# Epoch 129: train loss: 68.1042327881, validation loss: 60.4243965149
# Epoch 130: train loss: 68.2308959961, validation loss: 60.7713354429
# Epoch 131: train loss: 68.4564208984, validation loss: 60.2152287165
# Epoch 132: train loss: 68.1576919556, validation loss: 60.5322194099
# Epoch 133: train loss: 67.9972152710, validation loss: 60.2988597552
# Epoch 134: train loss: 68.3097686768, validation loss: 59.9347836177
# Epoch 135: train loss: 68.0786209106, validation loss: 60.0051288605
# Epoch 136: train loss: 67.9071197510, validation loss: 60.3726940155
# Epoch 137: train loss: 68.3681564331, validation loss: 60.2601873080
# Epoch 138: train loss: 68.1260681152, validation loss: 60.4773942629
# Epoch 139: train loss: 68.1568527222, validation loss: 59.7937513987
# Epoch 140: train loss: 68.0764312744, validation loss: 60.2909984589
# Epoch 141: train loss: 67.9128112793, validation loss: 60.6152264277
# Epoch 142: train loss: 68.3258056641, validation loss: 59.9135753314
# Epoch 143: train loss: 67.9593658447, validation loss: 59.7769144376
# Epoch 144: train loss: 68.2072677612, validation loss: 60.1337025960
# Epoch 145: train loss: 67.9471359253, validation loss: 60.2526281675
# Epoch 146: train loss: 68.0328979492, validation loss: 60.1854330699
# Epoch 147: train loss: 67.9856414795, validation loss: 60.0020755132
# Epoch 148: train loss: 68.0430450439, validation loss: 60.0659674009
# Epoch 149: train loss: 67.9338760376, validation loss: 60.7044407527
# Epoch 150: train loss: 67.9595260620, validation loss: 60.5332824389
# Epoch 151: train loss: 68.1063461304, validation loss: 60.0530646642
# Epoch 152: train loss: 67.9189224243, validation loss: 60.0128024419
# Epoch 153: train loss: 67.9787826538, validation loss: 59.7841211955
# Epoch 154: train loss: 67.6712646484, validation loss: 60.0653012594
# Epoch 155: train loss: 67.7772598267, validation loss: 60.6468691826
# Epoch 156: train loss: 67.7077102661, validation loss: 60.1003788312
# Epoch 157: train loss: 67.6664657593, validation loss: 60.4708547592
# Epoch 158: train loss: 67.9087600708, validation loss: 60.3664224943
# Epoch 159: train loss: 67.7611618042, validation loss: 59.8536345164
# Epoch 160: train loss: 67.9410705566, validation loss: 60.6918093363
# Epoch 161: train loss: 67.7127838135, validation loss: 60.3617884318
# Epoch 162: train loss: 67.8619689941, validation loss: 59.8825833003
# Epoch 163: train loss: 67.7912216187, validation loss: 60.2768658002
# Epoch 164: train loss: 67.8598175049, validation loss: 60.1582773527
# Epoch 165: train loss: 67.9127655029, validation loss: 60.1764303843
# Epoch 166: train loss: 67.7003021240, validation loss: 60.3175153732
# Epoch 167: train loss: 67.5538101196, validation loss: 60.0662013690
# Epoch 168: train loss: 67.8626022339, validation loss: 60.1637913386
# Epoch 169: train loss: 67.8653717041, validation loss: 60.2208894094
# Epoch 170: train loss: 67.5021896362, validation loss: 60.7766755422
# Epoch 171: train loss: 67.5878295898, validation loss: 60.2535854975
# Epoch 172: train loss: 67.7492370605, validation loss: 60.1656130155
# Epoch 173: train loss: 67.4840164185, validation loss: 59.7435830434
# Epoch 174: train loss: 67.5599746704, validation loss: 60.2261795998
# Epoch 175: train loss: 67.5011138916, validation loss: 60.7907969157
# Epoch 176: train loss: 67.6464920044, validation loss: 60.0165603956
# Epoch 177: train loss: 67.7069778442, validation loss: 60.1844140689
# Epoch 178: train loss: 67.6425018311, validation loss: 60.3429168065
# Epoch 179: train loss: 67.5842514038, validation loss: 60.1987551053
# Epoch 180: train loss: 67.5602569580, validation loss: 60.6949154536
# Epoch 181: train loss: 67.5457611084, validation loss: 60.9641712507
# Epoch 182: train loss: 67.4804611206, validation loss: 60.2009584109
# Epoch 183: train loss: 67.5156326294, validation loss: 61.0073021253
# Epoch 184: train loss: 67.6058197021, validation loss: 60.3715858459
# Epoch 185: train loss: 67.4941406250, validation loss: 60.5225917498
# Epoch 186: train loss: 67.5218048096, validation loss: 60.4786602656
# Epoch 187: train loss: 67.3666915894, validation loss: 60.8285344442
# Epoch 188: train loss: 67.2222290039, validation loss: 61.1677408218
# Epoch 189: train loss: 67.6252746582, validation loss: 61.4073788325
# Epoch 190: train loss: 67.4408798218, validation loss: 61.5675729116
# Epoch 191: train loss: 67.6687011719, validation loss: 61.0776702563
# Epoch 192: train loss: 67.5824966431, validation loss: 61.4940176010
# Epoch 193: train loss: 67.2417373657, validation loss: 60.7428332965
# Epoch 194: train loss: 67.3587951660, validation loss: 61.5541715622
# Epoch 195: train loss: 67.3861083984, validation loss: 61.3840991656
# Epoch 196: train loss: 67.4227600098, validation loss: 61.5093425115
# Epoch 197: train loss: 67.1777725220, validation loss: 61.2825498581
# Epoch 198: train loss: 67.1279067993, validation loss: 61.4336113930
# Epoch 199: train loss: 67.2518310547, validation loss: 61.7008040746
# Epoch 200: train loss: 67.3471603394, validation loss: 61.5006936391
# Epoch 201: train loss: 67.1376724243, validation loss: 61.5050962766
# Epoch 202: train loss: 66.9325256348, validation loss: 61.5439499219
# Epoch 203: train loss: 67.0647048950, validation loss: 62.0956575076
# Epoch 204: train loss: 67.1352081299, validation loss: 61.8105335236
# Epoch 205: train loss: 67.0379867554, validation loss: 61.6170830727
# Epoch 206: train loss: 67.1710281372, validation loss: 61.7468762398
# Epoch 207: train loss: 67.3876800537, validation loss: 62.0034979184
# Epoch 208: train loss: 67.0683364868, validation loss: 61.9321352641
# Epoch 209: train loss: 67.2527847290, validation loss: 62.0475942294
# Epoch 210: train loss: 67.0933990479, validation loss: 62.1327989896
# Epoch 211: train loss: 67.1422424316, validation loss: 61.8240850766
# Epoch 212: train loss: 67.2089309692, validation loss: 62.2922794024
# Epoch 213: train loss: 67.2204666138, validation loss: 61.7993510564
# Epoch 214: train loss: 67.4755477905, validation loss: 62.0578347842
# Epoch 215: train loss: 66.9858474731, validation loss: 61.7341596286
# Epoch 216: train loss: 66.9279708862, validation loss: 62.2511070569
# Epoch 217: train loss: 66.9255905151, validation loss: 62.2870669365
# Epoch 218: train loss: 66.9197082520, validation loss: 61.8529699643
# Epoch 219: train loss: 67.3144836426, validation loss: 62.2078833580
# Epoch 220: train loss: 67.0629730225, validation loss: 62.3762162526
# Epoch 221: train loss: 66.9254302979, validation loss: 61.4020147324
# Epoch 222: train loss: 67.1231384277, validation loss: 62.2274600665
# Epoch 223: train loss: 67.1077270508, validation loss: 61.9754656156
# Epoch 224: train loss: 66.7795486450, validation loss: 61.8772350947
# Epoch 225: train loss: 66.8635940552, validation loss: 61.9237090747
# Epoch 226: train loss: 66.8909988403, validation loss: 61.8763143222
# Epoch 227: train loss: 66.9331893921, validation loss: 61.8958454132
# Epoch 228: train loss: 66.8933334351, validation loss: 62.0472251574
# Epoch 229: train loss: 67.0673217773, validation loss: 62.0937484105
# Epoch 230: train loss: 67.1037902832, validation loss: 61.9751442273
# Epoch 231: train loss: 66.9046630859, validation loss: 62.0873543421
# Epoch 232: train loss: 67.1562271118, validation loss: 61.9491829872
# Epoch 233: train loss: 67.0128173828, validation loss: 62.4266789754
# Epoch 234: train loss: 67.1340560913, validation loss: 62.2224901517
# Epoch 235: train loss: 66.8950119019, validation loss: 61.9426848094
# Epoch 236: train loss: 66.8911514282, validation loss: 62.3398146629
# Epoch 237: train loss: 66.7349319458, validation loss: 62.1206086477
# Epoch 238: train loss: 66.8000717163, validation loss: 62.0948160489
# Epoch 239: train loss: 66.8134765625, validation loss: 62.0746765137
# Epoch 240: train loss: 66.9562683105, validation loss: 62.1421449979
# Epoch 241: train loss: 66.8929901123, validation loss: 61.8252083460
# Epoch 242: train loss: 66.8410110474, validation loss: 62.3029260635
# Epoch 243: train loss: 66.6706619263, validation loss: 62.2750898997
# Epoch 244: train loss: 67.1511001587, validation loss: 61.9244554838
# Epoch 245: train loss: 67.1257400513, validation loss: 62.0650000572
# Epoch 246: train loss: 67.0367813110, validation loss: 62.0597116152
# Epoch 247: train loss: 66.7297515869, validation loss: 62.0104931196
# Epoch 248: train loss: 66.9306106567, validation loss: 62.3754153252
# Epoch 249: train loss: 66.7505874634, validation loss: 62.1619270643
# Epoch 250: train loss: 66.8027191162, validation loss: 62.4542581240
# Epoch 251: train loss: 67.2957077026, validation loss: 62.5214211146
# Epoch 252: train loss: 67.0373687744, validation loss: 62.4397506714
# Epoch 253: train loss: 67.1247024536, validation loss: 62.5446422895
# Epoch 254: train loss: 66.9798965454, validation loss: 62.1683475176
# Epoch 255: train loss: 67.1281356812, validation loss: 62.4778731664
# Epoch 256: train loss: 66.7269287109, validation loss: 62.2105080287
# Epoch 257: train loss: 66.9719390869, validation loss: 62.3525838852
# Epoch 258: train loss: 67.0355529785, validation loss: 62.3364048004
# Epoch 259: train loss: 66.8565521240, validation loss: 62.3255635897
# Epoch 260: train loss: 66.9005203247, validation loss: 62.6433591843
# Epoch 261: train loss: 66.8496398926, validation loss: 62.4236474037
# Epoch 262: train loss: 66.7410430908, validation loss: 62.1318491300
# Epoch 263: train loss: 66.7189559937, validation loss: 61.9516032537
# Epoch 264: train loss: 66.7878417969, validation loss: 62.3721090953
# Epoch 265: train loss: 66.7995452881, validation loss: 62.1209664345
# Epoch 266: train loss: 66.7005691528, validation loss: 62.3211218516
# Epoch 267: train loss: 66.7716598511, validation loss: 62.6439482371
# Epoch 268: train loss: 66.7792510986, validation loss: 62.3532226880
# Epoch 269: train loss: 66.7780532837, validation loss: 62.0128866831
# Epoch 270: train loss: 66.8730621338, validation loss: 62.4371519089
# Epoch 271: train loss: 67.0242462158, validation loss: 62.1872960726
# Epoch 272: train loss: 66.7470932007, validation loss: 62.6198541323
# Epoch 273: train loss: 66.8111114502, validation loss: 62.1698985100
# Epoch 274: train loss: 66.7511444092, validation loss: 62.4665708542
# Epoch 275: train loss: 66.7186813354, validation loss: 62.0598707199
# Epoch 276: train loss: 66.5340728760, validation loss: 62.1382751465
# Epoch 277: train loss: 66.9981231689, validation loss: 62.2651265462
# Epoch 278: train loss: 66.8021011353, validation loss: 62.0738197962
# Epoch 279: train loss: 66.8362884521, validation loss: 62.4835143089
# Epoch 280: train loss: 66.6949691772, validation loss: 62.1863692602
# Epoch 281: train loss: 66.7807083130, validation loss: 62.2520473798
# Epoch 282: train loss: 66.9778976440, validation loss: 62.3164288203
# Epoch 283: train loss: 66.8722076416, validation loss: 62.1919131279
# Epoch 284: train loss: 66.6974105835, validation loss: 62.3708947500
# Epoch 285: train loss: 66.6700286865, validation loss: 62.3163078626
# Epoch 286: train loss: 66.5135574341, validation loss: 62.2181797028
# Epoch 287: train loss: 66.8436355591, validation loss: 62.1724222501
# Epoch 288: train loss: 66.8863677979, validation loss: 62.4769690832
# Epoch 289: train loss: 66.9572677612, validation loss: 62.0942074458
# Epoch 290: train loss: 66.6945877075, validation loss: 62.2585894267
# Epoch 291: train loss: 66.7586746216, validation loss: 62.2468581200
# Epoch 292: train loss: 66.6100006104, validation loss: 62.6164153417
# Epoch 293: train loss: 66.7637786865, validation loss: 62.3824669520
# Epoch 294: train loss: 66.5694656372, validation loss: 62.4393005371
# Epoch 295: train loss: 66.7299575806, validation loss: 62.6763294538
# Epoch 296: train loss: 67.0988998413, validation loss: 62.2709746361
# Epoch 297: train loss: 66.5853424072, validation loss: 62.6554239591
# Epoch 298: train loss: 66.9020233154, validation loss: 62.1176665624
# Epoch 299: train loss: 66.7216491699, validation loss: 62.2512432734
# Epoch 300: train loss: 66.8473892212, validation loss: 62.3818594615
# Epoch 301: train loss: 66.9751205444, validation loss: 62.0854762395
# Epoch 302: train loss: 66.6962966919, validation loss: 62.3018403053
# Epoch 303: train loss: 66.9267807007, validation loss: 62.0530791283
# Epoch 304: train loss: 66.5291290283, validation loss: 62.0431736310
# Epoch 305: train loss: 66.5430831909, validation loss: 62.1420893669
# Epoch 306: train loss: 66.8027648926, validation loss: 62.4248523712
# Epoch 307: train loss: 66.9722213745, validation loss: 62.6216486295
# Epoch 308: train loss: 66.9467086792, validation loss: 62.3147352537
# Epoch 309: train loss: 66.8035812378, validation loss: 62.1284025510
# Epoch 310: train loss: 66.6537551880, validation loss: 62.1965058645
# Epoch 311: train loss: 66.4524459839, validation loss: 62.5194263458
# Epoch 312: train loss: 66.6764602661, validation loss: 62.2607599894
# Epoch 313: train loss: 66.8389205933, validation loss: 62.4431950251
# Epoch 314: train loss: 66.5473937988, validation loss: 62.3136533101
# Epoch 315: train loss: 66.9431228638, validation loss: 61.9984745979
# Epoch 316: train loss: 66.8252868652, validation loss: 62.3725829124
# Epoch 317: train loss: 66.4683990479, validation loss: 62.4360157649
# Epoch 318: train loss: 66.8845138550, validation loss: 62.3517184258
# Epoch 319: train loss: 66.5183868408, validation loss: 62.2018946012
# Epoch 320: train loss: 66.5770568848, validation loss: 62.0950827599
# Epoch 321: train loss: 66.6332321167, validation loss: 62.8621724447
# Epoch 322: train loss: 66.7758941650, validation loss: 62.2954284350
# Epoch 323: train loss: 66.7835159302, validation loss: 62.4880164464
# Epoch 324: train loss: 66.8768920898, validation loss: 62.5369642576
# Epoch 325: train loss: 66.5637283325, validation loss: 62.2111822764
# Epoch 326: train loss: 66.6685791016, validation loss: 62.4554723104
# Epoch 327: train loss: 66.7162246704, validation loss: 62.2222685814
# Epoch 328: train loss: 66.6598052979, validation loss: 62.2875687281
# Epoch 329: train loss: 66.7266159058, validation loss: 62.4007735252
# Epoch 330: train loss: 66.5457763672, validation loss: 62.1548215548
# Epoch 331: train loss: 66.7088775635, validation loss: 62.3894664447
# Epoch 332: train loss: 66.6118240356, validation loss: 62.1523111661
# Epoch 333: train loss: 66.7498245239, validation loss: 62.3735688527
# Epoch 334: train loss: 66.7193679810, validation loss: 62.5805474917
# Epoch 335: train loss: 66.5615158081, validation loss: 62.2265477180
# Epoch 336: train loss: 66.6127090454, validation loss: 62.5193683306
# Epoch 337: train loss: 66.8561248779, validation loss: 62.3740363121
# Epoch 338: train loss: 66.6272888184, validation loss: 62.3712703387
# Epoch 339: train loss: 66.3646545410, validation loss: 62.3115617434
# Epoch 340: train loss: 66.9282150269, validation loss: 62.6026722590
# Epoch 341: train loss: 66.5556335449, validation loss: 62.4582355817
# Epoch 342: train loss: 66.6364974976, validation loss: 62.3720447222
# Epoch 343: train loss: 66.4127349854, validation loss: 62.1728820801
# Epoch 344: train loss: 66.3806762695, validation loss: 62.1796952883
# Epoch 345: train loss: 66.4009552002, validation loss: 62.4213097890
# Epoch 346: train loss: 66.8478393555, validation loss: 62.4825081825
# Epoch 347: train loss: 67.0318603516, validation loss: 62.8290120761
# Epoch 348: train loss: 66.4777908325, validation loss: 62.5172416369
# Epoch 349: train loss: 66.5465774536, validation loss: 62.4410061836
# Epoch 350: train loss: 66.6289749146, validation loss: 62.5123356183
# Epoch 351: train loss: 66.3629531860, validation loss: 62.1900924047
# Epoch 352: train loss: 66.5150909424, validation loss: 62.1527214050
# Epoch 353: train loss: 66.5077590942, validation loss: 62.5337298711
# Epoch 354: train loss: 66.6890411377, validation loss: 62.5054658254
# Epoch 355: train loss: 66.7970199585, validation loss: 62.2948486010
# Epoch 356: train loss: 66.4722366333, validation loss: 62.2916499774
# Epoch 357: train loss: 66.7664566040, validation loss: 62.2913366954
# Epoch 358: train loss: 66.4434204102, validation loss: 62.3267935117
# Epoch 359: train loss: 67.1433258057, validation loss: 62.1843204498
# Epoch 360: train loss: 67.0780105591, validation loss: 62.6502989133
# Epoch 361: train loss: 66.5546035767, validation loss: 62.3951454163
# Epoch 362: train loss: 66.6018524170, validation loss: 62.4322360357
# Epoch 363: train loss: 66.6874847412, validation loss: 62.4831698736
# Epoch 364: train loss: 66.6838607788, validation loss: 62.4847300847
# Epoch 365: train loss: 66.6102600098, validation loss: 62.3655854861
# Epoch 366: train loss: 66.8886184692, validation loss: 62.3316349983
# Epoch 367: train loss: 66.5208282471, validation loss: 62.5767925580
# Epoch 368: train loss: 66.5566864014, validation loss: 62.4240895907
# Epoch 369: train loss: 66.7778625488, validation loss: 62.4263477325
# Epoch 370: train loss: 66.8434829712, validation loss: 62.3014891942
# Epoch 371: train loss: 66.7781143188, validation loss: 62.4913876851
# Epoch 372: train loss: 66.6930694580, validation loss: 62.8168123563
# Epoch 373: train loss: 66.6957626343, validation loss: 62.4198018710
# Epoch 374: train loss: 66.6478424072, validation loss: 62.6083780924
# Epoch 375: train loss: 66.6166076660, validation loss: 62.2556619644
# Epoch 376: train loss: 66.3755416870, validation loss: 62.5635503133
# Epoch 377: train loss: 66.4833679199, validation loss: 62.5018382072
# Epoch 378: train loss: 66.6162567139, validation loss: 62.3374977112
# Epoch 379: train loss: 66.5644302368, validation loss: 62.0152784983
# Epoch 380: train loss: 66.6591567993, validation loss: 62.5329012871
# Epoch 381: train loss: 66.7519378662, validation loss: 62.6284139951
# Epoch 382: train loss: 66.9192733765, validation loss: 62.9009138743
# Epoch 383: train loss: 66.2963714600, validation loss: 62.5109847387
# Epoch 384: train loss: 66.6272277832, validation loss: 62.8470212619
# Epoch 385: train loss: 66.8940048218, validation loss: 62.4615481695
# Epoch 386: train loss: 66.3962631226, validation loss: 62.6658356984
# Epoch 387: train loss: 66.6511764526, validation loss: 62.4952532450
# Epoch 388: train loss: 66.4676437378, validation loss: 62.6078313192
# Epoch 389: train loss: 66.5455245972, validation loss: 62.2102198601
# Epoch 390: train loss: 66.5367431641, validation loss: 62.2880663872
# Epoch 391: train loss: 66.4978408813, validation loss: 62.2235894203
# Epoch 392: train loss: 66.7395248413, validation loss: 62.4683675766
# Epoch 393: train loss: 66.7143707275, validation loss: 62.5519968669
# Epoch 394: train loss: 66.2996215820, validation loss: 62.1648472150
# Epoch 395: train loss: 66.8888854980, validation loss: 62.2988899549
# Epoch 396: train loss: 66.8534011841, validation loss: 62.4378404617
# Epoch 397: train loss: 66.5043106079, validation loss: 62.4256437620
# Epoch 398: train loss: 66.6305236816, validation loss: 62.5888109207
# Epoch 399: train loss: 66.6980361938, validation loss: 62.4727687836
# Epoch 400: train loss: 66.5151138306, validation loss: 62.4124946594
# Epoch 401: train loss: 66.3810195923, validation loss: 62.4247431755
# Epoch 402: train loss: 66.3925018311, validation loss: 62.4746869405
# Epoch 403: train loss: 66.6177062988, validation loss: 62.3364383380
# Epoch 404: train loss: 66.4072799683, validation loss: 62.6729133924
# Epoch 405: train loss: 66.4488067627, validation loss: 62.5570495923
# Epoch 406: train loss: 66.7616424561, validation loss: 62.5169407527
# Epoch 407: train loss: 66.3795852661, validation loss: 63.1192056338
# Epoch 408: train loss: 66.6693115234, validation loss: 62.4738616943
# Epoch 409: train loss: 66.8674011230, validation loss: 62.5372714996
# Epoch 410: train loss: 66.4800796509, validation loss: 62.6062959035
# Epoch 411: train loss: 66.5392150879, validation loss: 62.4768703779
# Epoch 412: train loss: 66.7862777710, validation loss: 62.3946887652
# Epoch 413: train loss: 66.3109741211, validation loss: 62.3782010078
# Epoch 414: train loss: 66.5056915283, validation loss: 62.4159560204
# Epoch 415: train loss: 66.5251998901, validation loss: 62.9832220078
# Epoch 416: train loss: 66.3829116821, validation loss: 62.6312704086
# Epoch 417: train loss: 66.6302795410, validation loss: 63.0233402252
# Epoch 418: train loss: 66.7234420776, validation loss: 62.6484295527
# Epoch 419: train loss: 66.7416381836, validation loss: 62.3008451462
# Epoch 420: train loss: 66.6235427856, validation loss: 62.3683915138
# Epoch 421: train loss: 66.3222656250, validation loss: 62.2971041997
# Epoch 422: train loss: 66.5863189697, validation loss: 62.3852405548
# Epoch 423: train loss: 66.7524185181, validation loss: 62.3489743869
# Epoch 424: train loss: 66.6598052979, validation loss: 62.5484835307
# Epoch 425: train loss: 66.3956451416, validation loss: 62.2196162542
# Epoch 426: train loss: 66.7530975342, validation loss: 62.3294970194
# Epoch 427: train loss: 66.5604858398, validation loss: 62.4453700384
# Epoch 428: train loss: 66.7006835938, validation loss: 62.5336990356
# Epoch 429: train loss: 66.4160537720, validation loss: 62.2841804822
# Epoch 430: train loss: 66.4301986694, validation loss: 62.3118481636
# Epoch 431: train loss: 66.5534515381, validation loss: 62.2868914604
# Epoch 432: train loss: 66.3345565796, validation loss: 62.6288978259
# Epoch 433: train loss: 66.6438674927, validation loss: 62.2911745707
# Epoch 434: train loss: 66.4015197754, validation loss: 62.8475004832
# Epoch 435: train loss: 66.7810211182, validation loss: 62.7241271337
# Epoch 436: train loss: 66.6335067749, validation loss: 62.5157675743
# Epoch 437: train loss: 66.4199829102, validation loss: 62.3523726463
# Epoch 438: train loss: 66.3222885132, validation loss: 62.3409199715
# Epoch 439: train loss: 66.3087158203, validation loss: 62.4573637644
# Epoch 440: train loss: 66.4803924561, validation loss: 62.5819530487
# Epoch 441: train loss: 66.5104904175, validation loss: 62.5696768761
# Epoch 442: train loss: 66.4785919189, validation loss: 62.5566469828
# Epoch 443: train loss: 66.3159103394, validation loss: 63.2014633814
# Epoch 444: train loss: 66.3712463379, validation loss: 62.3123796781
# Epoch 445: train loss: 66.7182006836, validation loss: 62.1605987549
# Epoch 446: train loss: 66.3448562622, validation loss: 62.7546292941
# Epoch 447: train loss: 66.6563796997, validation loss: 62.5406142871
# Epoch 448: train loss: 66.6135482788, validation loss: 62.9822049141
# Epoch 449: train loss: 66.5825729370, validation loss: 62.5903910001
# Epoch 450: train loss: 66.5536727905, validation loss: 62.4172050158
# Epoch 451: train loss: 66.5667419434, validation loss: 62.4427059491
# Epoch 452: train loss: 66.4968338013, validation loss: 62.1682084401
# Epoch 453: train loss: 66.5406341553, validation loss: 62.5398149490
# Epoch 454: train loss: 66.7181015015, validation loss: 62.3043778737
# Epoch 455: train loss: 66.5767440796, validation loss: 62.4463287989
# Epoch 456: train loss: 66.6192169189, validation loss: 62.2637434006
# Epoch 457: train loss: 66.7607803345, validation loss: 62.3729481697
# Epoch 458: train loss: 66.7093200684, validation loss: 62.4502560298
# Epoch 459: train loss: 66.3953933716, validation loss: 62.6113187472
# Epoch 460: train loss: 66.6923370361, validation loss: 62.4513842265
# Epoch 461: train loss: 66.5603179932, validation loss: 62.2039421399
# Epoch 462: train loss: 66.6155548096, validation loss: 62.4795853297
# Epoch 463: train loss: 66.4301757812, validation loss: 62.5411287944
# Epoch 464: train loss: 66.5013580322, validation loss: 62.8091599147
# Epoch 465: train loss: 66.5512619019, validation loss: 62.3787139257
# Epoch 466: train loss: 66.5646057129, validation loss: 62.3057052294
# Epoch 467: train loss: 66.7832946777, validation loss: 62.5880611738
# Epoch 468: train loss: 66.3969650269, validation loss: 62.8119759560
# Epoch 469: train loss: 66.6010971069, validation loss: 62.4067926407
# Epoch 470: train loss: 66.4023666382, validation loss: 62.3502206802
# Epoch 471: train loss: 66.1671981812, validation loss: 62.4996657372
# Epoch 472: train loss: 66.3837661743, validation loss: 62.3185737928
# Epoch 473: train loss: 66.3098144531, validation loss: 62.3135364850
# Epoch 474: train loss: 66.7917938232, validation loss: 62.3357513746
# Epoch 475: train loss: 66.3765182495, validation loss: 62.5341835022
# Epoch 476: train loss: 66.3269348145, validation loss: 62.6596339544
# Epoch 477: train loss: 66.7096023560, validation loss: 62.5264870326
# Epoch 478: train loss: 66.6136322021, validation loss: 62.1383579572
# Epoch 479: train loss: 66.2596435547, validation loss: 62.4383126895
# Epoch 480: train loss: 66.4354705811, validation loss: 62.3619650205
# Epoch 481: train loss: 66.2862854004, validation loss: 62.5588386854
# Epoch 482: train loss: 66.3773880005, validation loss: 62.3062410355
# Epoch 483: train loss: 66.2903213501, validation loss: 62.4809660912
# Epoch 484: train loss: 66.3119277954, validation loss: 62.6209797859
# Epoch 485: train loss: 66.3803329468, validation loss: 62.9107480049
# Epoch 486: train loss: 66.3611297607, validation loss: 62.0388962428
# Epoch 487: train loss: 66.6350936890, validation loss: 62.6288342476
# Epoch 488: train loss: 66.3976287842, validation loss: 62.3177742958
# Epoch 489: train loss: 66.4797363281, validation loss: 62.3375695546
# Epoch 490: train loss: 66.7229385376, validation loss: 62.3584790230
# Epoch 491: train loss: 66.5521392822, validation loss: 62.4029563268
# Epoch 492: train loss: 66.4593658447, validation loss: 62.3928208351
# Epoch 493: train loss: 66.2575225830, validation loss: 62.7651810646
# Epoch 494: train loss: 66.4088592529, validation loss: 62.2988589605
# Epoch 495: train loss: 66.5221862793, validation loss: 62.1382505099
# Epoch 496: train loss: 66.3298721313, validation loss: 62.2192975680
# Epoch 497: train loss: 66.5253372192, validation loss: 62.6435527802
# Epoch 498: train loss: 66.4253540039, validation loss: 62.3537387848
# Epoch 499: train loss: 66.2407760620, validation loss: 62.6954127947
# Epoch 500: train loss: 66.5306549072, validation loss: 62.5364896456
# Finished Training

# %%
# train_loss = [l[0] for l in train_network.train_loss_hist]
# val_loss = [l[0] for l in train_network.val_loss_hist]

epochs = np.arange(0, net_params['epochs'])

plt.figure(figsize=(15,8))
plt.plot(epochs, train_network.train_loss_hist, linewidth=2, color='tab:orange', label='Training loss')
plt.plot(epochs, train_network.val_loss_hist, linewidth=2, color='tab:blue', label='Validation loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %%
# dummy_input = torch.randn(256, 9)  # Create a dummy input for visualization
# make_dot(network(dummy_input).mean(), params=dict(list(network.named_parameters())))

# %%
# import torchvision
# from torchview import draw_graph
# model_graph = draw_graph(network, input_size=(256, 9), expand_nested=True)
# model_graph.visual_graph

# %%
index = 9
x_test = X[index,:,:]
y_test = input_data[index,:,:]

# %%
x_test.shape, y_test.shape
# Out:
# ((99, 9), (99, 3))

# %%
Train = False

y_net = np.zeros((num_snaps,num_joints))
x_test_flat, y_test_flat = network.process_data(x_test.reshape((1,num_snaps,9)), y_test.reshape(1,num_snaps,3))
x_test_std = network.standardize_data(x_test_flat)
# y_test_std = network.standardize_data(y_test_flat)

for i in range(x_test.shape[0]):
    y_net[i,:] = network.forward(torch.from_numpy(x_test_std[i,:]).float().reshape(1,-1), Train)

# %%
y_test_flat.shape
# Out:
# (3, 99)

# %%
total_params = sum(p.numel() for p in network.parameters())
total_params
# Out:
# 31903

# %%
#plot predicted and actual trajectories 
plt.figure(figsize = (10,10))
plt.subplot(3,1,1)
plt.plot(y_test_flat[0,:],linewidth = 2, label = 'reference traj')
plt.plot(y_net[:,0],'--',linewidth = 2, label = 'pred traj')
plt.xlabel('time step')
plt.ylabel('theta_1')
plt.legend()

plt.subplot(3,1,2)
plt.plot(y_test_flat[1,:],linewidth = 2, label = 'reference traj')
plt.plot(y_net[:,1],':',linewidth = 2, label = 'pred traj')
plt.xlabel('time step')
plt.ylabel('theta_2')
plt.legend()

plt.subplot(3,1,3)
plt.plot(y_test_flat[2,:],linewidth = 2, label = 'reference traj')
plt.plot(y_net[:,2],'-.',linewidth = 2, label = 'pred traj')
plt.xlabel('time step')
plt.ylabel('theta_3')
plt.legend()
plt.show()

# %%
"""CONTROL AND ADAPTATION"""
# Out:
# 'CONTROL AND ADAPTATION'

# %%
#simultaneous adaptation and control
dt = 0.01
t_end = 30
t_eval = np.arange(0,t_end,dt)
num_steps = t_eval.shape[0]
theta_d = np.zeros((num_steps, num_joints))
theta_dot_d = np.zeros((num_steps, num_joints))
theta_ddot_d = np.zeros((num_steps, num_joints))

num_cycles = t_end/10
arg = np.linspace(0, num_cycles*2*np.pi,num_steps)


for i in range(num_steps):
    theta_d[i,:] = -0.5*np.array([np.sin(2*arg[i]), np.sin(2*arg[i]), np.sin(2*arg[i])])

    theta_dot_d[i,:] = -0.5*np.array([(2*arg[-1]/t_end)*np.cos(2*arg[i]), (2*arg[-1]/t_end)*np.cos(2*arg[i]), (2*arg[-1]/t_end)*np.cos(2*arg[i])])

    theta_ddot_d[i,:] = -0.5*np.array([-((2*arg[-1]/t_end)**2)*np.cos(2*arg[i]), -((2*arg[-1]/t_end)**2)*np.cos(2*arg[i]), -((2*arg[-1]/t_end)**2)*np.cos(2*arg[i])])


tau = np.zeros((num_steps, num_joints))

theta_t = np.zeros_like(theta_d)
theta_dot_t = np.zeros_like(theta_dot_d)
theta_ddot_t = np.zeros_like(theta_dot_d)

Error = np.zeros((num_steps,num_joints))
Error_dot = np.zeros((num_steps, num_joints))

a = np.zeros((Conv,num_steps))
a[:,0] = network.A_weight().reshape(-1)

# %%
#plot_trajectory
plt.figure(figsize = (10,10))
plt.subplot(3,1,1)
plt.plot(theta_d[:,0], linewidth = 2, label = 'reference traj')
plt.xlabel('time step')
plt.ylabel('theta_1')
plt.legend()

plt.subplot(3,1,2)
plt.plot(theta_d[:,1], linewidth = 2,  label = 'reference traj')
plt.xlabel('time step')
plt.ylabel('theta_2')
plt.legend()

plt.subplot(3,1,3)
plt.plot(theta_d[:,2], linewidth = 2,  label = 'reference traj')
plt.xlabel('time step')
plt.ylabel('theta_3')
plt.legend()
plt.show()

# %%
k = 9
P = 0.5
Ks = np.diag(np.array([0.1, 0.1, 0.1]))
L = np.diag(np.array([2, 2, 2]))

adapt_freq = 500
train_network = torch.load('NN_arch.pth')

begin_time = time.time()
adaptation_time = 0
control_time = 0
for i in range(num_steps-1):
    t1 = time.time()
    error = (theta_t[i,:] - theta_d[i,:]).reshape(-1,1)
    error_dot = (theta_dot_t[i,:] - theta_dot_d[i,:]).reshape(-1,1)
    s =  error_dot + L @ error
    theta_dot_r = theta_dot_d[i,:].reshape(-1,1) - L @ error
    theta_ddot_r = theta_ddot_d[i,:].reshape(-1,1) - L @ error_dot

    input_vec = np.concatenate((theta_t[i,:],theta_dot_t[i,:], theta_dot_r.reshape(-1,), theta_ddot_r.reshape(-1,)))

    input_vec_tensor = torch.from_numpy(input_vec.reshape(1,-1)).float()
    Y_out = network.Y_out(input_vec_tensor)
    a_dot = -P * Y_out.squeeze() @ s
    t2 = time.time()
    tau[i,:] = (Y_out.squeeze().T @ a[:,i].reshape(-1,1) - Ks @ s - k * np.sign(s)).reshape(-1,)
    t3 = time.time()
    a[:,i+1] = a[:,i] + a_dot.reshape(-1,) * dt
    t4 = time.time()
    theta_ddot_t[i,:] = robot_changed.accel(theta_t[i,:], theta_dot_t[i,:], tau[i,:]).reshape(-1,)
    theta_dot_t[i+1,:] = theta_ddot_t[i,:] * dt + theta_dot_t[i,:]
    theta_t[i+1,:] = theta_t[i,:] + theta_dot_t[i+1,:]*dt
    
    Error[i,:] = error.reshape(-1,)
    Error_dot[i,:] = error_dot.reshape(-1,)
    t5 = time.time() 
    """ADAPTATION"""
    if i % adapt_freq==0 and i!=0:
        adapt_params = {}
        adapt_params['epochs'] = 10
        adapt_params['batch_size'] = adapt_freq 
        
        x_adapt = np.concatenate((theta_t[i-adapt_freq:i,:],theta_dot_t[i-adapt_freq:i,:], theta_ddot_t[i-adapt_freq:i,:]), axis = 1)
        u_adapt = tau[i-adapt_freq:i,:]
        train_network.model_pipeline_adapt(x_adapt, u_adapt, adapt_params, print_epoch=False)
    t6 = time.time()
    adaptation_time = adaptation_time+(t6-t3) +(t2-t1)
    control_time = control_time + (t3-t1)+(t5-t4)
end_time = time.time()
# Out:
# Finished Training
# Finished Training
# Finished Training
# Finished Training
# Finished Training

# %%
adapt_taken = adaptation_time/num_steps
adapt_taken
# Out:
# 0.0010915428002675374

# %%
control_taken = control_time/num_steps
control_taken
# Out:
# 0.0007907779216766357

# %%
plt.figure(figsize = (10,10))
plt.subplot(3,1,1)
plt.plot(theta_d[:,0], linewidth = 2, label = 'reference traj')
plt.plot(theta_t[:,0],'--',linewidth = 2, label = 'pred traj')
plt.xlabel('time step')
plt.ylabel('theta_1')
plt.legend()

plt.subplot(3,1,2)
plt.plot(theta_d[:,1],linewidth = 2, label = 'reference traj')
plt.plot(theta_t[:,1],':',linewidth = 2, label = 'pred traj')
plt.xlabel('time step')
plt.ylabel('theta_2')
plt.legend()

plt.subplot(3,1,3)
plt.plot(theta_d[:,2],linewidth = 2, label = 'reference traj')
plt.plot(theta_t[:,2],'-.',linewidth = 2, label = 'pred traj')
plt.xlabel('time step')
plt.ylabel('theta_3')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.subplot(3,1,1)
plt.plot(theta_dot_d[:,0], linewidth = 2, label = 'reference traj')
plt.plot(theta_dot_t[:,0],'--',linewidth = 2, label = 'pred traj')
plt.xlabel('t')
plt.ylabel('theta_dot_1')
plt.legend()

plt.subplot(3,1,2)
plt.plot(theta_dot_d[:,1],linewidth = 2, label = 'reference traj')
plt.plot(theta_dot_t[:,1],':',linewidth = 2, label = 'pred traj')
plt.xlabel('t')
plt.ylabel('theta_dot_2')
plt.legend()

plt.subplot(3,1,3)
plt.plot(theta_dot_d[:,2],linewidth = 2, label = 'reference traj')
plt.plot(theta_dot_t[:,2],'-.',linewidth = 2, label = 'pred traj')
plt.xlabel('t')
plt.ylabel('theta_dot_3')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.plot(Error, linewidth = 2, label = 'error')
plt.xlabel('t')
plt.ylabel('error')
# Out:
# Text(0, 0.5, 'error')

# %%
plt.figure(figsize = (15,5))
plt.subplot(3,1,1)
plt.plot(tau[:,0], linewidth = 1, label = 'u1')
plt.xlabel('t')
plt.ylabel('tau_1')
plt.legend()

plt.subplot(3,1,2)
plt.plot(tau[:,1],linewidth = 1, label = 'u2')
plt.xlabel('t')
plt.ylabel('tau_2')
plt.legend()

plt.subplot(3,1,3)
plt.plot(tau[:,2],linewidth = 1, label = 'u3')
plt.xlabel('t')
plt.ylabel('tau_3')
plt.legend()
plt.show()

# %%
error_adapt = np.linalg.norm((theta_t-theta_d),axis=1)

# %%
error_adapt.shape
# Out:
# (3000,)

# %%
error_adapt_rmse = np.linalg.norm(error_adapt)/np.sqrt(t_eval.shape[0])

print("RMSE theta Error in Adaptive Model", error_adapt_rmse)
# Out:
# RMSE theta Error in Adaptive Model 0.9142286053535467

# %%
error_adapt_dot = np.linalg.norm((theta_dot_t-theta_dot_d),axis=1)
error_adapt_rmse_dot = np.linalg.norm(error_adapt_dot)/np.sqrt(t_eval.shape[0])

print("RMSE theta dot Error in Adaptive Model", error_adapt_rmse_dot)
# Out:
# RMSE theta dot Error in Adaptive Model 1.088105193062921

# %%
# RMSE_130 = np.array([error_adapt_rmse])
# np.savetxt('RMSE_130.txt', RMSE_130, delimiter=',')

# %%
control_effort = np.linalg.norm((tau), axis = 1)

# %%
control_effort.shape
# Out:
# (3000,)

# %%
average_control_effort = np.sum(control_effort)/num_steps

# %%
average_control_effort
# Out:
# 11.688806853407751

# %%
traj_adapt = {"error_theta_adapt":(theta_t-theta_d)}
scipy.io.savemat("changed_results/" + 'num_traj'+str(num_train)+"adapt_CNN_error.mat",traj_adapt)

# %%
# traj_CNN = {"theta_t":theta_t, "theta_d":theta_d, "theta_dot_t": theta_dot_t}
# scipy.io.savemat("changed_results/CNN_result.mat",traj_CNN)
